# %%
import pandas as pd
import plotly.express as  px
import numpy as np

# %%
dados = pd.read_csv("frota-de-veiculos-ufmg-2020.csv",encoding = "ISO-8859-1", sep=';', header=2)

# %%
dados
# Out:
#      Ano Fabbricação    Placa  Idade Combustível         nº Chassis  \
# 0             2007.0  GMF5169     14        Flex  9BD15822774948345
# 1             2012.0  GMF7099      9        Flex  9BWPB45Z0D4076670
# 2             2006.0  GMF5092     15        Flex  9BWGF07X07P007585
# 3             2005.0  GMF4764     16      Diesel  9BWR682WX5R530359
# 4             2008.0  GMF5427     13        Flex  9BD17140A85178053
# ..               ...      ...    ...         ...                ...
# 257           2008.0  GMF5416     13      Outros  9BWGF07X18P018452
# 258           2011.0  GMF6842     10        Flex  9BWMF07X3CP017766
# 259           2011.0  GXM9257     10        Flex  9BWKB05U2CP049295
# 260           2010.0  HMR4791     11        Flex  9BD27803MA7234146
# 261           2010.0  GMF6544     11        Flex  9BWMF07X0BP017612
#
#                             Destinação                   Tipo  \
# 0           TRANSPORTE DE  PASSAGEIROS          PAS/AUTOMOVEL
# 1           TRANSPORTE DE  PASSAGEIROS          PAS/AUTOMOVEL
# 2     TRANSP PASS , CARGA E MANUTENÇÃO  MIS/CAMION./C.FECHADA
# 3           TRANSPORTE DE  PASSAGEIROS             PAS/ONIBUS
# 4           TRANSPORTE DE  PASSAGEIROS          PAS/AUTOMOVEL
# ..                                 ...                    ...
# 257   TRANSP PASS , CARGA E MANUTENÇÃO  MIS/CAMION./C.FECHADA
# 258   TRANSP PASS , CARGA E MANUTENÇÃO  MIS/CAMION./C.FECHADA
# 259     TRANSPORTE PASSAGEIROS E CARGA   CAR/CAMION./C.ABERTA
# 260  TRANSPORTE DE PASSAGEIROS E CARGA          PAS/AUTOMOVEL
# 261   TRANSP PASS , CARGA E MANUTENÇÃO  MIS/CAMION./C.FECHADA
#
#          Unidade de lotação                     Setor lotação Valor Aquisição
# 0      ARQ-ESC. ARQUITETURA                      ARQ-GABINETE           23900
# 1      EBA ESC. BELAS ARTES                     EBA DIRETORIA           44049
# 2      EBA ESC. BELAS ARTES    EBA - LOGISTICA E SERV.OPERAC.           37975
# 3    ESC. CIENC. INFORMACAO       ESC. CIENC. INFORMACAO-SGER          283000
# 4    ESC. CIENC. INFORMACAO       ESC. CIENC. INFORMACAO-SGER           29175
# ..                      ...                               ...             ...
# 257                   DEMAI  DEMAI DIV. MAQ. EQUIP. ESPECIAIS           41400
# 258                   DEMAI  DEMAI DIV. MAQ. EQUIP. ESPECIAIS           49000
# 259                   DEMAI  DEMAI DIV. MAQ. EQUIP. ESPECIAIS           34616
# 260                   DEMAI  DEMAI DIV. MAQ. EQUIP. ESPECIAIS           31818
# 261                   DEMAI                 DEMAI HIDRAULICA            44260
#
# [262 rows x 10 columns]
